# %%
# Import Functions
import numpy as np
import matplotlib.pyplot as plt
import os
import cartopy.crs as ccrs
from useful_functions import data_compiler
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /glade/u/apps/opt/conda/envs/npl-2022b/share/proj failed

# %% [markdown]
# # Compile Data from all times

# %%
vars_list = os.listdir("/glade/work/acheung/TC_Genesis") # Determine Variables
# varinput = input('Enter Number (1. Absolute Vorticity at 850 hPa, 2. Column Relative Humidity, 3. Vertical Shear, 5. Potential Intensity, 6. Saturation Deficit): ')

inputarray = np.asarray(range(0,5))
inputarray = np.concatenate([inputarray[0:3],inputarray[-2:] + 1]) + 1
for varinput in inputarray:

    # Variable Names (neat)
    strofvarnames = ['Absolute Vorticity (850 hPa)', 'Column Relative Humidity', 'Vertical Shear','Mistake', 'Potential Intensity', 'Saturation Deficit']

    # Index of variable chosen
    varchosen = strofvarnames[int(varinput) - 1]
    vardesired = vars_list[int(varinput) - 1]

    # Compile Data for a Variable for all timesteps (including years and coordinates)
    Varcompiled, YearList, lons, lats = data_compiler(vardesired) 
    lonsmeshed, latsmeshed = np.meshgrid(lons, lats)

    # Variable Names for Directory Use
    strofvardirnames = ['Absolute_Vorticity_850_hPa', 'Column_Relative_Humidity', 'Vertical_Shear','Mistake', 'Potential_Intensity', 'Saturation_Deficit']

    # Legend Units
    stroflegendunits = ['Absolute Vorticity ($s^{-1}$)','Relative Humidity (Fractional)','Vertical Shear (m $s^{-1}$)','Mistake','Potential Intensity (m $s^{-1}$)','Saturation Deficit (g $kg^{-1}$)']

    # Set Minimum and Maximum ranges for pcolormesh plot

    if int(varinput) == 1: # Absolute Vorticity (850 hPa)
        minrange = 0
        maxrange = 0.0003
        cmapdesired = 'viridis'

    elif int(varinput) == 2:
        minrange = 0.4
        maxrange = 1
        cmapdesired = 'YlGn'

    elif int(varinput) == 3:
        minrange = 0
        maxrange = 50
        cmapdesired = 'viridis'
    elif int(varinput) == 5:
        minrange = 0
        maxrange = 110
        cmapdesired = 'viridis'
    elif int(varinput) == 6:
        minrange = -60
        maxrange = 0
        cmapdesired = 'YlGn'

    # Create Plots in Loop
    month = range(0,12) # Index of month to be selected

    for currentmonth in month: # Loop of current month (Sorted by month)
        for yearstep in range(0,Varcompiled.shape[0]): # Loop of current year
            fig = plt.figure(figsize=(10,7))
            varcurrent = Varcompiled[yearstep,:,:,currentmonth] # Call compiled data at specific month and year

            if int(varinput) == 1: # I took the absolute value of the entire matrix.... NOTE that we could also just multiple SH by -1... To be tested later...
                varcurrent = np.absolute(varcurrent)

            # Create cartopy plot
            ax = plt.axes(projection=ccrs.Robinson())
            ax.set_global()
            contourmap = ax.pcolormesh(lonsmeshed, latsmeshed, varcurrent, transform=ccrs.PlateCarree(),cmap=cmapdesired,vmin=minrange,vmax=maxrange)
            ax.coastlines()
            ax.gridlines()
            currentyear = YearList[yearstep] # Call current year

            # Create string for month
            if currentmonth+1<10: # add one to the index for actual month
                monthstr = '0' + str(currentmonth+1)
            else:
                monthstr = str(currentmonth+1)

            ax.set_title(varchosen+' (' + monthstr +'/' + str(currentyear + ')')) # Variable of plot (month/year)
            cbar = plt.colorbar(contourmap,extend='both') # Defined Colorbar Range using vmin/vmax
            cbar.ax.set_ylabel(stroflegendunits[int(varinput) - 1])
            plt.tight_layout()
            # Save Figure
            plt.savefig('/glade/work/acheung/Initial_Plots/'+ strofvardirnames[int(varinput) - 1]+
                        '/' + monthstr + '/' +
                        strofvardirnames[int(varinput) - 1] + '_' +currentyear+'_'+ monthstr +'.jpg',dpi=250)

            plt.close()
            print('Variable: '+ varchosen +' Month: ' + monthstr + ' Year: ' + str(currentyear))

        # Create GIF
        os.chdir('/glade/work/acheung/Initial_Plots/'+strofvardirnames[int(varinput) - 1] + '/' + monthstr) # Change Directory
        command = 'convert -delay 100 -loop 0 *.jpg ' + strofvardirnames[int(varinput) - 1] + '_' + monthstr + '.gif' # String command for GIF
        os.system(command) # Execute command to make GIF
# Out:
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1950
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1951
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1952
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1953
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1954
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1955
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1956
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1957
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1958
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1959
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1960
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1961
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1962
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1963
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1964
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1965
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1966
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1967
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1968
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1969
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1970
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1971
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1972
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1973
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1974
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1975
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1976
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1977
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1978
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1979
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1980
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1981
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1982
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1983
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1984
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1985
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1986
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1987
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1988
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1989
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1990
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1991
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1992
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1993
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1994
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1995
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1996
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1997
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1998
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 1999
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2000
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2001
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2002
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2003
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2004
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2005
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2006
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2007
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2008
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2009
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2010
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2011
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2012
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2013
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2014
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2015
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2016
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2017
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2018
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2019
# Variable: Absolute Vorticity (850 hPa) Month: 01 Year: 2020
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1950
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1951
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1952
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1953
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1954
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1955
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1956
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1957
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1958
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1959
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1960
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1961
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1962
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1963
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1964
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1965
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1966
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1967
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1968
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1969
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1970
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1971
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1972
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1973
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1974
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1975
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1976
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1977
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1978
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1979
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1980
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1981
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1982
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1983
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1984
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1985
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1986
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1987
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1988
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1989
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1990
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1991
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1992
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1993
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1994
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1995
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1996
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1997
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1998
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 1999
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2000
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2001
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2002
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2003
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2004
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2005
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2006
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2007
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2008
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2009
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2010
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2011
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2012
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2013
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2014
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2015
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2016
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2017
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2018
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2019
# Variable: Absolute Vorticity (850 hPa) Month: 02 Year: 2020
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1950
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1951
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1952
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1953
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1954
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1955
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1956
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1957
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1958
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1959
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1960
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1961
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1962
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1963
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1964
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1965
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1966
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1967
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1968
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1969
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1970
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1971
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1972
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1973
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1974
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1975
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1976
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1977
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1978
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1979
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1980
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1981
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1982
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1983
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1984
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1985
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1986
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1987
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1988
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1989
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1990
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1991
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1992
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1993
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1994
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1995
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1996
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1997
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1998
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 1999
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2000
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2001
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2002
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2003
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2004
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2005
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2006
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2007
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2008
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2009
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2010
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2011
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2012
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2013
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2014
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2015
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2016
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2017
# Variable: Absolute Vorticity (850 hPa) Month: 03 Year: 2018

# %%
# Commands to make file directories

# # for i in range(0,len(strofvardirnames)):
# #     os.system('mkdir ' + '/glade/work/acheung/Initial_Plots/'+strofvardirnames[i])

# for i in range(0,len(strofvardirnames)):
#     for m in range(1,13):
#         if m < 10:
#             os.system('mkdir ' + '/glade/work/acheung/Initial_Plots/' + strofvardirnames[i] + '/0' + str(m))
#         else:
#             os.system('mkdir ' + '/glade/work/acheung/Initial_Plots/' + strofvardirnames[i] + '/' + str(m))
